#   4.200149695078532,
#   4.256539265314738,
#   4.207780520121257,
#   4.179337978363037,
#   4.130819638570149,
#   4.177060604095459,
#   4.115260521570842,
#   4.166110575199127,
#   4.087573925654094,
#   3.900491952896118,
#   4.6770486036936445,
#   4.358093857765198,
#   4.442185282707214],
#  [3.887122631072998,
#   3.7674145698547363,
#   3.9682908058166504,
#   3.8975844383239746,
#   3.873314142227173,
#   3.9917898178100586,
#   4.323883771896362,
#   3.9451564153035483,
#   4.011636137962341,
#   4.052767674128215,
#   4.547674655914307,
#   4.191074291865031,
#   4.0111039479573565,
#   4.711595217386882,
#   4.372742414474487,
#   4.1053009033203125,
#   4.751906394958496,
#   4.110836505889893,
#   4.489995718002319,
#   4.063527901967366,
#   4.732513904571533,
#   4.008951981862386,
#   4.119651238123576,
#   4.262189269065857,
#   4.38442341486613,
#   4.070325930913289,
#   4.4504594802856445,
#   4.100710550944011,
#   4.194007953008016,
#   4.079310417175293,
#   4.31938624382019,
#   3.9096831480662027,
#   4.155696948369344,
#   4.038829644521077,
#   4.875297546386719,
#   4.2319291432698565,
#   3.671939492225647,
#   4.056307792663574,
#   3.731607675552368,
#   4.1465364297231035,
#   4.171918074289958,
#   4.16737699508667,
#   5.0170520941416425,
#   4.280879497528076,
#   4.277155637741089,
#   4.031559785207112,
#   3.6695006489753723,
#   4.295019149780273,
#   4.782880385716756,
#   4.147578875223796,
#   4.777178208033244,
#   4.111715475718181,
#   4.2359092235565186,
#   4.122485081354777,
#   3.6571921507517495,
#   4.110203504562378,
#   4.274573644002278,
#   3.917904257774353,
#   4.07300740480423,
#   4.081582387288411,
#   4.612565755844116,
#   4.209720293680827,
#   3.7647977471351624,
#   4.272592663764954,
#   4.327533324559529,
#   4.048385302225749,
#   4.110216975212097,
#   4.0594015916188555,
#   4.1538465817769366,
#   4.037160873413086,
#   4.222817341486613,
#   4.312038103739421,
#   4.699530839920044,
#   3.8798927068710327,
#   4.426741600036621],
#  [None],
#  [None],
#  [4.708561817804973,
#   ['ooa'],
#   ['ooa'],
#   4.478523413340251,
#   1.008447249730428,
#   ['ooa'],
#   0.9547355969746908,
#   0.6388982534408569,
#   ['ooa'],
#   0.5059475302696228,
#   0.9895572662353516,
#   4.582112073898315,
#   ['ooa'],
#   [],
#   1.153354326883952,
#   1.987732172012329,
#   5.195531487464905,
#   1.8907567660013835,
#   1.0216028690338135,
#   1.975199540456136,
#   0.9097570578257242,
#   2.00685985883077,
#   0.9765602946281433,
#   0.2351686954498291,
#   5.275700569152832,
#   2.9561278223991394,
#   ['ooa'],
#   3.0524654388427734,
#   ['ooa'],
#   4.696591297785441,
#   [],
#   1.9819994767506917,
#   1.166446288426717,
#   ['ooa'],
#   ['ooa'],
#   0.0,
#   1.0287034511566162,
#   [],
#   [],
#   0.5787432193756104,
#   ['ooa'],
#   ['ooa'],
#   1.063667853673299,
#   ['ooa'],
#   1.136496861775716,
#   ['ooa'],
#   ['ooa'],
#   3.1001253922780356,
#   0.949547290802002,
#   4.814959446589152,
#   1.2103357315063477,
#   0.5133312344551086,
#   1.2476933002471924,
#   0.432489275932312,
#   ['ooa'],
#   4.809552033742269,
#   1.184024413426717,
#   2.030409892400106,
#   0.9401403665542603,
#   0.510646402835846,
#   ['ooa'],
#   4.344196081161499,
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   2.501219113667806,
#   4.892670631408691,
#   ['ooa'],
#   2.158151467641195,
#   1.169840971628825,
#   4.6762315432230634,
#   [],
#   2.1108226776123047,
#   5.514894008636475,
#   4.792344510555267,
#   ['ooa'],
#   5.004202902317047],
#  [['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   [],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   [],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa'],
#   ['ooa']],
#  [None],
#  [None],
#  [None],
#  [None]]

# %%
def cleaned_mean(arr):

    if arr==[None]:
        m=0
    else:
        print(arr)
        arr = list(filter(lambda x: x!= ['ooa'], arr))
        arr = list(filter(lambda x: x!= [], arr))
        df = pd.DataFrame(arr,columns=['value'])
        print(df)
        max_treshold=df['value'].quantile(0.80)
        df=df[df['value']<max_treshold]
        df=df[df['value']>0]
        m=np.mean(df.value)
    return m

# %%
def remove_ooa(arr,m):
    count=0
    array=[]
    if arr==[None]:
        array=[None]
    else:
        if np.isnan(array).all():
            array=[None]
        else:
            for i in range(len(arr)):

                if type(arr[i]) == type([]):
                    if arr[i]==[]:
                        array.append(m)
                    elif arr[i]==['ooa']:
                        count+=1
                        array.append(m)
                else:
                    array.append(arr[i])
    return array,count

# %%
def clean(x):
    mod_x=[]

    for j in x:
   
        mn=cleaned_mean(j)
        s,_=remove_ooa(j,mn)
        mod_x.append(s)
    return mod_x

# %%
new_sT=clean(f_Ts)
new_sT
# Out:
# [2.055833339691162, 1.9576690196990967, 2.023791790008545, 2.01080060005188, 2.1762696901957193, 2.1277058124542236, 2.2919114430745444, 2.2578051686286926, 2.1078476905822754, 2.147546370824178, 1.9963027636210124, 2.0021296739578247, 2.117537260055542, 1.751115620136261, 1.967948357264201, 2.007030189037323, 2.199958006540934, 2.1140586535135903, 2.1236324310302734, 2.0676231384277344, 2.3019189834594727, 2.1160638332366943, 2.1745107173919678, 2.212984323501587, 2.2226202487945557, 2.050846040248871, 2.122559070587158, 2.123535633087158, 2.283245801925659, 2.151749849319458, 2.1735206246376038, 1.9902066588401794, 1.9698597192764282, 6.222367127736409, 1.6114956736564636, 2.25775408744812, 2.1258997917175293, 2.213203549385071, 2.134583055973053, 2.0878856778144836, 2.1509817242622375, 2.581609845161438, 1.5844621062278748, 2.1616068482398987, 2.1106457710266113, 2.1690601110458374, 2.0597512125968933, 2.1788296699523926, 2.1599368254343667, 2.1907461881637573, 1.5507450699806213, 2.1533012986183167, 2.2008946736653647, 2.0081101059913635, 2.1304050286610923, 2.1552918553352356, 2.148831367492676, 2.2265304724375405, 1.9837009906768799, 1.9430851141611736, 2.071732997894287, 2.051687479019165, 2.1579757928848267, 2.2401697635650635, 2.1143857638041177, 2.2264589071273804, 1.9577794075012207, 2.0495179891586304, 2.147081196308136, 2.1599372029304504, 2.171330153942108, 2.2171172499656677, 2.342595398426056, 2.2935306429862976, 2.2053630352020264]
# Empty DataFrame
# Columns: [value]
# Index: []
#   3.8798927068710327,
#   4.426741600036621],
#  [None],
#  [None],
#  [4.708561817804973,
#   nan,
#   nan,
#   4.478523413340251,
#   1.008447249730428,
#   nan,
#   0.9547355969746908,
#   0.6388982534408569,
#   nan,
#   0.5059475302696228,
#   0.9895572662353516,
#   4.582112073898315,
#   nan,
#   nan,
#   1.153354326883952,
#   1.987732172012329,
#   5.195531487464905,
#   1.8907567660013835,
#   1.0216028690338135,
#   1.975199540456136,
#   0.9097570578257242,
#   2.00685985883077,
#   0.9765602946281433,
#   0.2351686954498291,
#   5.275700569152832,
#   2.9561278223991394,
#   nan,
#   3.0524654388427734,
#   nan,
#   4.696591297785441,
#   nan,
#   1.9819994767506917,
#   1.166446288426717,
#   nan,
#   nan,
#   0.0,
#   1.0287034511566162,
#   nan,
#   nan,
#   0.5787432193756104,
#   nan,
#   nan,
#   1.063667853673299,
#   nan,
#   1.136496861775716,
#   nan,
#   nan,
#   3.1001253922780356,
#   0.949547290802002,
#   4.814959446589152,
#   1.2103357315063477,
#   0.5133312344551086,
#   1.2476933002471924,
#   0.432489275932312,
#   nan,
#   4.809552033742269,
#   1.184024413426717,
#   2.030409892400106,
#   0.9401403665542603,
#   0.510646402835846,
#   nan,
#   4.344196081161499,
#   nan,
#   nan,
#   nan,
#   nan,
#   2.501219113667806,
#   4.892670631408691,
#   nan,
#   2.158151467641195,
#   1.169840971628825,
#   4.6762315432230634,
#   nan,
#   2.1108226776123047,
#   5.514894008636475,
#   4.792344510555267,
#   nan,
#   5.004202902317047],
#  [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [None],
#  [None],
#  [None],
#  [None]]

# %%
def reliability_matrix(arr):
    rel_matrix=[]

    for i in range(len(arr)):
        if arr[i]==[None]:
            s=[None]
        else:
            df = pd.DataFrame(arr[i],columns=['value'])
            print(arr[i]) 
            outliers = setup(df ,silent=True,numeric_features = ["value"])
            knn = create_model('knn')
            knn_results = assign_model(knn)
            s=np.array(knn_results.Anomaly_Score)
            s=1-s
            s=np.round(100*s,2)
            s=[0 if x==100 else x for x in s]
        rel_matrix.append(s)
    return rel_matrix

# %%
rel_matrix=reliability_matrix(new_sT)
# Out:
# <style type="text/css">
# #T_1604f_row2_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1604f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1604f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1604f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1604f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1604f_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1604f_row0_col1" class="data row0 col1" >2616</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1604f_row1_col0" class="data row1 col0" >Original Data</td>
#       <td id="T_1604f_row1_col1" class="data row1 col1" >(74, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1604f_row2_col0" class="data row2 col0" >Missing Values</td>
#       <td id="T_1604f_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1604f_row3_col0" class="data row3 col0" >Numeric Features</td>
#       <td id="T_1604f_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1604f_row4_col0" class="data row4 col0" >Categorical Features</td>
#       <td id="T_1604f_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1604f_row5_col0" class="data row5 col0" >Ordinal Features</td>
#       <td id="T_1604f_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1604f_row6_col0" class="data row6 col0" >High Cardinality Features</td>
#       <td id="T_1604f_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1604f_row7_col0" class="data row7 col0" >High Cardinality Method</td>
#       <td id="T_1604f_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1604f_row8_col0" class="data row8 col0" >Transformed Data</td>
#       <td id="T_1604f_row8_col1" class="data row8 col1" >(74, 0)</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1604f_row9_col0" class="data row9 col0" >CPU Jobs</td>
#       <td id="T_1604f_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1604f_row10_col0" class="data row10 col0" >Use GPU</td>
#       <td id="T_1604f_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1604f_row11_col0" class="data row11 col0" >Log Experiment</td>
#       <td id="T_1604f_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1604f_row12_col0" class="data row12 col0" >Experiment Name</td>
#       <td id="T_1604f_row12_col1" class="data row12 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1604f_row13_col0" class="data row13 col0" >USI</td>
#       <td id="T_1604f_row13_col1" class="data row13 col1" >27f5</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1604f_row14_col0" class="data row14 col0" >Imputation Type</td>
#       <td id="T_1604f_row14_col1" class="data row14 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1604f_row15_col0" class="data row15 col0" >Iterative Imputation Iteration</td>
#       <td id="T_1604f_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1604f_row16_col0" class="data row16 col0" >Numeric Imputer</td>
#       <td id="T_1604f_row16_col1" class="data row16 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1604f_row17_col0" class="data row17 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_1604f_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1604f_row18_col0" class="data row18 col0" >Categorical Imputer</td>
#       <td id="T_1604f_row18_col1" class="data row18 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1604f_row19_col0" class="data row19 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_1604f_row19_col1" class="data row19 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1604f_row20_col0" class="data row20 col0" >Unknown Categoricals Handling</td>
#       <td id="T_1604f_row20_col1" class="data row20 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1604f_row21_col0" class="data row21 col0" >Normalize</td>
#       <td id="T_1604f_row21_col1" class="data row21 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1604f_row22_col0" class="data row22 col0" >Normalize Method</td>
#       <td id="T_1604f_row22_col1" class="data row22 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1604f_row23_col0" class="data row23 col0" >Transformation</td>
#       <td id="T_1604f_row23_col1" class="data row23 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1604f_row24_col0" class="data row24 col0" >Transformation Method</td>
#       <td id="T_1604f_row24_col1" class="data row24 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1604f_row25_col0" class="data row25 col0" >PCA</td>
#       <td id="T_1604f_row25_col1" class="data row25 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1604f_row26_col0" class="data row26 col0" >PCA Method</td>
#       <td id="T_1604f_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1604f_row27_col0" class="data row27 col0" >PCA Components</td>
#       <td id="T_1604f_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1604f_row28_col0" class="data row28 col0" >Ignore Low Variance</td>
#       <td id="T_1604f_row28_col1" class="data row28 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1604f_row29_col0" class="data row29 col0" >Combine Rare Levels</td>
#       <td id="T_1604f_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1604f_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_1604f_row30_col0" class="data row30 col0" >Rare Level Threshold</td>
#       <td id="T_1604f_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      10:19:29
# Status     . . . . . . . . . . . . . . . . . .         Fitting 0.05 Fraction
# Estimator  . . . . . . . . . . . . . . . . . .  K-Nearest Neighbors Detector
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <module>
# ----> 1 rel_matrix=reliability_matrix(new_sT)
#
# Input In [27], in reliability_matrix(arr)
#       9 print(arr[i])
#      10 outliers = setup(df ,silent=True,numeric_features = ["value"])
# ---> 11 knn = create_model('knn')
#      12 knn_results = assign_model(knn)
#      13 s=np.array(knn_results.Anomaly_Score)
#
# File ~/.local/lib/python3.8/site-packages/pycaret/anomaly.py:505, in create_model(model, fraction, verbose, fit_kwargs, **kwargs)
#     442 def create_model(
#     443     model: Union[str, Any],
#     444     fraction: float = 0.05,
#    (...)
#     447     **kwargs
#     448 ):
#     450     """
#     451     This function trains a given model from the model library. All available
#     452     models can be accessed using the ``models`` function.
#    (...)
#     502
#     503     """
# --> 505     return pycaret.internal.tabular.create_model_unsupervised(
#     506         estimator=model,
#     507         fraction=fraction,
#     508         fit_kwargs=fit_kwargs,
#     509         verbose=verbose,
#     510         **kwargs,
#     511     )
#
# File ~/.local/lib/python3.8/site-packages/pycaret/internal/tabular.py:2692, in create_model_unsupervised(estimator, num_clusters, fraction, ground_truth, round, fit_kwargs, verbose, system, add_to_model_list, raise_num_clusters, X_data, display, **kwargs)
#    2688                 raise RuntimeError(
#    2689                     "Could not form valid cluster separation. Try a different dataset or model."
#    2690                 )
#    2691     else:
# -> 2692         pipeline_with_model.fit(data_X, **fit_kwargs)
#    2693 model_fit_end = time.time()
#    2695 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/.local/lib/python3.8/site-packages/pycaret/internal/pipeline.py:118, in Pipeline.fit(self, X, y, **fit_kwargs)
#     117 def fit(self, X, y=None, **fit_kwargs):
# --> 118     result = super().fit(X, y=y, **fit_kwargs)
#     120     self._carry_over_final_estimator_fit_vars()
#     121     return result
#
# File ~/.local/lib/python3.8/site-packages/imblearn/pipeline.py:281, in Pipeline.fit(self, X, y, **fit_params)
#     278 with _print_elapsed_time('Pipeline',
#     279                          self._log_message(len(self.steps) - 1)):
#     280     if self._final_estimator != "passthrough":
# --> 281         self._final_estimator.fit(Xt, yt, **fit_params)
#     282 return self
#
# File ~/.local/lib/python3.8/site-packages/pyod/models/knn.py:190, in KNN.fit(self, X, y)
#     173 """Fit detector. y is ignored in unsupervised methods.
#     174
#     175 Parameters
#    (...)
#     186     Fitted estimator.
#     187 """
#     189 # validate inputs X and y (optional)
# --> 190 X = check_array(X)
#     191 self._set_n_classes(y)
#     193 self.neigh_.fit(X)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      68                   "passing these as positional arguments will "
#      69                   "result in an error".format(", ".join(args_msg)),
#      70                   FutureWarning)
#      71 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72 return f(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:533, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     530                     has_pd_integer_array = True
#     532     if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 533         dtype_orig = np.result_type(*dtypes_orig)
#     535 if dtype_numeric:
#     536     if dtype_orig is not None and dtype_orig.kind == "O":
#     537         # if input is object, convert to float.
#
# File <__array_function__ internals>:5, in result_type(*args, **kwargs)
#
# ValueError: at least one array or dtype is required

# %%
def shape(a):
    if not type(a) == list:
        return []
    return [len(a)] + shape(a[0])

# %%
def loop(s,r):
    dim=len(shape(r))
    if dim==1:
        for i in range(len(r)):
            if not r[i]==None:
                if r[i]<75:
                    s[i]=s[i-1]
                    print(s[i])
                    
    else:
        for j in range(len(s)):
            loop(s[j],r[j])
        
    return s

# %%
rel_matrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <module>
# ----> 1 rel_matrix
#
# NameError: name 'rel_matrix' is not defined

# %%
filtered_sT=loop(new_sT,rel_matrix) 
filtered_sT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <module>
# ----> 1 filtered_sT=loop(new_sT,rel_matrix)
#       2 filtered_sT
#
# NameError: name 'rel_matrix' is not defined

# %%
for i in filtered_sT:
    print(len(i))
# Out:
# 84
# 84
# 84
# 84
# 1
# 1
# 124
# 84
# 1
# 1
# 1
# 1

# %%
maxLen = max(map(len, filtered_sT))
maxLen
# Out:
# 124

# %%
input_sT=[]
for i in filtered_sT:
    if not i==[None]:
        d=maxLen//len(i)
        r=maxLen%len(i)
        arr=i*d+i[:r]
        input_sT.append(arr)
input_sT=np.array(input_sT)

# %%
input_sT.shape
# Out:
# (6, 124)

# %%
output = open('feature_vector/FV_side_{}.pkl'.format(name), 'wb')
pickle.dump(input_sT, output)
output.close()
